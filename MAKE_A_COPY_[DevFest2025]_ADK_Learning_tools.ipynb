# %% [markdown]
# <a href="https://colab.research.google.com/github/HINGWENYI/42-discovery_piscine-python/blob/main/MAKE_A_COPY_%5BDevFest2025%5D_ADK_Learning_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Welcome to Your ADK Adventure - Tools & Memory! 🚀
#
# Welcome, Agent Architect! This notebook is your guide to giving your AI agents two essential superpowers: custom tools and conversational memory.
#
# By the end of this adventure, you will be able to:
#
# - **Build a Foundational Agent**: Create a simple but effective AI agent from scratch using the Google Agent Development Kit (ADK).
#
# - **Grant New Skills with Custom Tools**: Teach an agent to perform new tasks by connecting it to external APIs, like a real-time weather service.
#
# - **Create a Team of Agents**: Assemble a multi-agent system where a primary agent can delegate specialized tasks to other agents.
#
# - **Master Conversational Memory**: Understand the critical role of Sessions in enabling agents to remember previous interactions, handle feedback, and carry on a coherent conversation.
#
#
# Let's get this adventure started!

# %% [markdown]
# ## Original Author
#
# Qingyue (Annie) Wang - Developer Advocate (Google)
#
# [LinkedIn](https://www.linkedin.com/in/qingyuewang/)
#
# [X](https://twitter.com/qingyuewang)
#
# email anniewangtech0510@Gmail.com
#
#
# ```
#   (\__/)
#   (•ㅅ•)
#   /づ  📚      Enjoy learning AI Agents :)
# ```

# %% [markdown]
# -------------
# ### 🎁 🛑 Important Prerequisite: Setup Your Environment! 🛑 🎁
# -----------------------------------------------------------------------------
#
# 👉 **Get Your API Key HERE**: https://codelabs.developers.google.com/onramp/instructions#1
#
#  -----------------------------------------------------------------------------

# %% [markdown]
# ```
#  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️
#    /\_/\     /\_/\     /\_/\      /\_/\       /\_/\
#   ( ^_^ )   ( -.- )   ( >_< )   ( =^.^= )    ( o_o )
# ```

# %% [markdown]
# ## Part 0: Setup & Authentication 🔑
#
# First things first, let's get all our tools ready. This step installs the necessary libraries and securely configures your Google API key so your agents can access the power of Gemini.

# %%
# !pip install google-adk google-generativeai -q

# --- Import all necessary libraries for our entire adventure ---
import os
import re
import asyncio
from IPython.display import display, Markdown
import google.generativeai as genai
from google.adk.agents import Agent
from google.adk.tools import google_search
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService, Session
from google.genai.types import Content, Part
from getpass import getpass

print("✅ All libraries are ready to go!")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# ✅ All libraries are ready to go!

# %%
# --- Securely Configure Your API Key ---

# Prompt the user for their API key securely
api_key = getpass('Enter your Google API Key: ')

# Get Your API Key HERE 👉 https://codelabs.developers.google.com/onramp/instructions#0
# Configure the generative AI library with the provided key
genai.configure(api_key=api_key)

# Set the API key as an environment variable for ADK to use
os.environ['GOOGLE_API_KEY'] = api_key

print("✅ API Key configured successfully! Let the fun begin.")
# Out:
# Enter your Google API Key: ··········
# ✅ API Key configured successfully! Let the fun begin.

# %% [markdown]
# ---
# ## Part 1: Your First Agent - The Day Trip Genie 🧞
#
# Meet your first creation! The `day_trip_agent` is a simple but powerful assistant. We're making it a little smarter by teaching it to understand **budget constraints**.
#
# * **Agent**: The brain of the operation, defined by its instructions, tools, and the AI model it uses.
# * **Session**: The conversation history. For this simple agent, it's just a container for a single request-response.
# * **Runner**: The engine that connects the `Agent` and the `Session` to process your request and get a response.

# %% [markdown]
# ```
# +--------------------------------------------------+
# |         Spontaneous Day Trip Agent 🤖            |
# |--------------------------------------------------|
# |  Model: gemini-2.5-flash                         |
# |  Description:                                    |
# |   Generates full-day trip itineraries based on   |
# |   mood, interests, and budget                    |
# |--------------------------------------------------|
# |  🔧 Tools:                                       |
# |   - Google Search                                |
# |--------------------------------------------------|
# |  🧠 Capabilities:                                |
# |   - Budget Awareness (cheap / splurge)           |
# |   - Mood Matching (adventurous, relaxing, etc.)  |
# |   - Real-Time Info (hours, events)               |
# |   - Morning / Afternoon / Evening plan           |
# +--------------------------------------------------+
#
#             ▲
#             |
#     +------------------+
#     |   User Input     |
#     |------------------|
#     |  Mood            |
#     |  Interests       |
#     |  Budget          |
#     +------------------+
#
#             |
#             ▼
#
# +--------------------------------------------------+
# |             Output: Markdown Itinerary           |
# |--------------------------------------------------|
# | - Time blocks (Morning / Afternoon / Evening)    |
# | - Venue names with links and hours               |
# | - Budget-matching activities                     |
# +--------------------------------------------------+
# ```

# %%
# --- Agent Definition ---

def create_day_trip_agent():
    """Create the Spontaneous Day Trip Generator agent"""
    return Agent(
        name="day_trip_agent",
        model="gemini-2.5-flash",
        description="Agent specialized in generating spontaneous full-day itineraries based on mood, interests, and budget.",
        instruction="""
        You are the "Spontaneous Day Trip" Generator 🚗 - a specialized AI assistant that creates engaging full-day itineraries.

        Your Mission:
        Transform a simple mood or interest into a complete day-trip adventure with real-time details, while respecting a budget.

        Guidelines:
        1. **Budget-Aware**: Pay close attention to budget hints like 'cheap', 'affordable', or 'splurge'. Use Google Search to find activities (free museums, parks, paid attractions) that match the user's budget.
        2. **Full-Day Structure**: Create morning, afternoon, and evening activities.
        3. **Real-Time Focus**: Search for current operating hours and special events.
        4. **Mood Matching**: Align suggestions with the requested mood (adventurous, relaxing, artsy, etc.).

        RETURN itinerary in MARKDOWN FORMAT with clear time blocks and specific venue names.
        """,
        tools=[google_search]
    )

day_trip_agent = create_day_trip_agent()
print(f"🧞 Agent '{day_trip_agent.name}' is created and ready for adventure!")
# Out:
# 🧞 Agent 'day_trip_agent' is created and ready for adventure!

# %%
# --- A Helper Function to Run Our Agents ---
# We'll use this function throughout the notebook to make running queries easy.

async def run_agent_query(agent: Agent, query: str, session: Session, user_id: str, is_router: bool = False):
    """Initializes a runner and executes a query for a given agent and session."""
    print(f"\n🚀 Running query for agent: '{agent.name}' in session: '{session.id}'...")

    runner = Runner(
        agent=agent,
        session_service=session_service,
        app_name=agent.name
    )

    final_response = ""
    try:
        async for event in runner.run_async(
            user_id=user_id,
            session_id=session.id,
            new_message=Content(parts=[Part(text=query)], role="user")
        ):
            if not is_router:
                # Let's see what the agent is thinking!
                print(f"EVENT: {event}")
            if event.is_final_response():
                final_response = event.content.parts[0].text
    except Exception as e:
        final_response = f"An error occurred: {e}"

    if not is_router:
     print("\n" + "-"*50)
     print("✅ Final Response:")
     display(Markdown(final_response))
     print("-"*50 + "\n")

    return final_response

# --- Initialize our Session Service ---
# This one service will manage all the different sessions in our notebook.
session_service = InMemorySessionService()
my_user_id = "adk_adventurer_001"

# %%
# --- Let's test the Day Trip Genie! ---

async def run_day_trip_genie():
    # Create a new, single-use session for this query
    day_trip_session = await session_service.create_session(
        app_name=day_trip_agent.name,
        user_id=my_user_id
    )

    # Note the new budget constraint in the query!
    query = "Plan a relaxing and artsy day trip near Sunnyvale, CA. Keep it affordable!"
    print(f"🗣️ User Query: '{query}'")

    await run_agent_query(day_trip_agent, query, day_trip_session, my_user_id)

await run_day_trip_genie()
# Out:
# 🗣️ User Query: 'Plan a relaxing and artsy day trip near Sunnyvale, CA. Keep it affordable!'
#
# 🚀 Running query for agent: 'day_trip_agent' in session: 'bb5896eb-502f-498b-bc48-52c19291b46e'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Here's a relaxing and artsy day trip near Sunnyvale, CA, designed with affordability in mind for Friday, March 13, 2026:
#
# ## Relaxing & Artsy Day Trip near Sunnyvale, CA (Affordable)
#
# This itinerary focuses on free or low-cost artistic and serene experiences, with suggestions for affordable meals.
#
# ### Morning (11:00 AM - 1:30 PM): Immerse in Art and Sculptures
#
# *   **Cantor Arts Center at Stanford University & Rodin Sculpture Garden (Stanford, CA)**
#     *   **Description:** Begin your day exploring the diverse collections at the Cantor Arts Center, which features art from various cultures and periods. Afterward, take a leisurely stroll through the adjacent Rodin Sculpture Garden, an impressive outdoor space showcasing over 20 bronze sculptures by Auguste Rodin. The blend of indoor gallery space and the tranquil outdoor garden provides a perfect artsy and relaxing start to your day.
#     *   **Cost:** Free admission.
#     *   **Operating Hours (March 13, 2026):** Open Wednesday to Sunday, 11 AM - 5 PM.
#
# ### Lunch (1:30 PM - 2:30 PM): Affordable Bites in Palo Alto
#
# *   **Oren's Hummus or Mediterranean Wraps (Palo Alto, CA)**
#     *   **Description:** Head to downtown Palo Alto for an affordable and delicious lunch. Oren's Hummus offers a delightful array of hummus plates, shawarma wraps, and falafel bowls with fresh ingredients and generous portions. Alternatively, Mediterranean Wraps is known for its tasty and filling Mediterranean cuisine, with options like falafel and kufta kebabs at reasonable prices.
#     *   **Cost:** Affordable (expect to spend $10-$20 per person).
#
# ### Afternoon (2:30 PM - 4:30 PM): Serenity in Bloom
#
# *   **Elizabeth F. Gamble Garden (Palo Alto, CA)**
#     *   **Description:** After lunch, find tranquility at the Elizabeth F. Gamble Garden, a historic 2.5-acre property featuring formal gardens and a beautiful rose garden. It's a wonderful place for a peaceful walk, offering benches to sit and relax amidst vibrant flora.
#     *   **Cost:** Free admission.
#     *   **Operating Hours (March 13, 2026):** Generally open during daylight hours; confirm specific closing time for Friday in March, but typically accessible until at least 5 PM.
#
# ### Late Afternoon / Early Evening (4:30 PM - 6:00 PM): Sunnyvale Public Art Walk
#
# *   **Self-Guided Public Art Tour (Sunnyvale, CA)**
#     *   **Description:** Return to Sunnyvale and take a relaxing self-guided tour of the city's extensive public art collection. Sunnyvale boasts over 200 public art pieces, including the "Sun Flair" program which features 26 sun sculptures uniquely transformed by local artists, installed in various city parks. You can view these pieces, often including murals and sculptures, in an outdoor setting.
#     *   **Cost:** Free.
#
# ### Evening (6:00 PM onwards): Affordable Dinner & Relaxed Ambiance
#
# *   **Dinner in Sunnyvale (Various Locations)**
#     *   **Description:** Enjoy an affordable dinner in Sunnyvale. Options could include local eateries on Murphy Avenue or exploring diverse cuisines available in the area. For a casual and budget-friendly meal, consider places with good reviews for a relaxed atmosphere.
#     *   **Cost:** Affordable (expect to spend $15-$25 per person).
#
# Enjoy your relaxing and artsy day trip!"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='california.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEDtoiU2h639gcETroVlcgF6lnBPZ-L7aw-ME7_G49d0MTDQrUzifDsfpeTfIuTuU-0Q66VpjTsHfg-QBB6y8754eHdWD5dVcotTZDNME_1x5G8IVaa7b0BOr9AcwuZUSpGA2iAugmBOy_FhGatDUE6563NqrFuqAPQS8wCl5wTckqkTEFRCyntB8iTZUhiYHytokuUFuCvSCumgTyEIg=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='sojournswithsue.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH9D6ZMYlvOF3D29f4IzuG-UHjXzLdps8XlgSLLmC-mEh8AG7pXiEzqD7Tjp7llZhlRbgyhn4S-m94eb9jysZwdnEOH7Nk5ozqEUoKzJK6CSzxRnpi1JPUIPK2Ckorgrr5dziNe0f-WrTy6K4f5NQq9lhYT9c5WweoulD48YCC8Tw=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='foodaholix.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGcXwsqECdMhNozCsT10evJoXhCPsfoFL5Np4j0-AOjzfOgc-ynIjEUbZ0096XU673Oqk05Qt_NCRY1m7flQzxcMGu67Y1ZasceWhFQ91dI_s1L0J_Idjud13OkFZegd5Xg_v2Z6fDriH3nJqNmQ3HEy0Ffsuo_e9YPjinwjZ8IE7r3'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='wanderlog.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGl4RFRkxdiagWQQZ-TZfUN4TtuzqF-ZQ3rEQZATWuRuYYDgXOL1H7YHW6HFTLwg6l0oWitVHXtlkrVWV6Sj2o37BQdhzhSiNriaRJvdiReeH7DRfDv5fv76u7UCULbtLG1UIfVCz9iMgwOlJyN7Ci28FeSoJNAtnF0ZkFWsJFWsoz3pb0j'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='thesanfranciscopeninsula.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGCms1sUZy0CS_AR7FWySbBCgEW8HWjDj5d2QeCJt7qAnKQWgMq640Wis3GdKUadx_33_ZbuSjT5tP7-wn6kd69HEdXe5RydobsN9JtqRtAacT4iNPLOM5CNiYuficrxdUTi0fGnBYcy3ZQvemTJwprHYZPqjYn8SR_ypu-6Mtci3t0KV6QRlz8CD4fkQ=='
#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=895,
#         start_index=773,
#         text='The blend of indoor gallery space and the tranquil outdoor garden provides a perfect artsy and relaxing start to your day.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=929,
#         start_index=900,
#         text='*   **Cost:** Free admission.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=1015,
#         start_index=934,
#         text='*   **Operating Hours (March 13, 2026):** Open Wednesday to Sunday, 11 AM - 5 PM.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=1368,
#         start_index=1231,
#         text="Oren's Hummus offers a delightful array of hummus plates, shawarma wraps, and falafel bowls with fresh ingredients and generous portions."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=1526,
#         start_index=1369,
#         text='Alternatively, Mediterranean Wraps is known for its tasty and filling Mediterranean cuisine, with options like falafel and kufta kebabs at reasonable prices.'
#       )
#     ),
#     <... 5 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFBU4csoaLxBJ7WJzu_rcWFNp6pfJx3iC2ZkKdUopnyu6bZrckVQ8Xm3TNLItPPIiMKw-uTEROenz9VCNVWJEVfRL_Gcg8n7ZGvtCghD2IlbKvtFxW5jOk3dXzAtKoNlxy_huEmrH7V5wLClL66VK64016oZunvcUL8t73MD6ggRJbcB8WnoevA67ebBtKWBvRrp5_BAwaPkk-cR3o8B3jdljXB4w-WbAHt">affordable things to do in Santa Clara</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGghOtNo14Unp62Dgrnk12nh_8GbzqBRqvxjQewbqL96bntBjh5f0KsD4rBNGMSx5h5pXMls2ERPGCynBnMrmHL2tNr5BHxFgnb-wdyT9lSQwAnUOovB2MAMIQIN67yZvyqLCecDrD-YO2ETcgdwWIqE-Pd-Tao7CxJLEfBlZ3ghpkgQxWZv-YA8odPcGAlPsVZxSD6k-n_kgVmBZasOKifApjNVsfXvlVBFMM=">affordable things to do in Mountain View</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFHIIsO7TIxa68y6Ad-ppuYeksAtlpXsfWvjxgTmPNWfTS1P8nAkgBwdog3e7PHmKTJaQ54b83sLcDvPnnYTldteY7b2NtdlPOQpCYqClXmzE77ox9Mxf-n3XRnHZYE9LdBGixEqwtBD4PzdrjaZbtIhsy0b0JBBc7GdpSsVwtWNKW6aqHRoLJGYgOPmpJvphCfyAQC8hhRMKnHGdKUmLrCF34GRQI=">affordable art galleries Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHXCjnnSAk2lJV-pWHzUwTJx88uzWZvYijdiXSVspR-dTrV9IapUcsl_nwLeJbIQrFB0HonVfJOYSmKDsXETrod04bUP45JXtg439EgsAtaE5Qfd7Xc5OelfBTX4PDkEaY9LBsZPYn4zE4N573Ljdx1FBAw_0LUoYwd9Hcu3oqYLS8uipNlsPyhl_qjkN4hH4r4ByqFrqvCbaXsbBjrCqDYa-EJJVo=">free art museums near Sunnyvale CA</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGGIIqV4ASfhVBjPAomTxXngxWU056eVQxHUIdWIbdfnzQMcSKaupZTlXBE6myIdW8UZh8ZuR0ET_PaBzkVGtkIHhrBPE4Q8gS3v6ZyrCINmRY5S4_Rm-XMlhdygt_T5BUkhEexzdzfC9LW51PA6H19y1o02RjyEmIGb9e_Da3-kxA2tZjylJ0sTNDGGxyPf-CnN928QKEsveWgHmhvFm5E3QFRpHm8uQ45GG0H1DpIeww=">outdoor sculpture parks near Sunnyvale CA free</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHy0aZmoE-lH1Aa2ndg8yXr13XKt0oRNAjPF1gXsdcnpax94a2pYdkpV0msrBtTqHIqBQ3SoelmdROTXpVlCpP5djs9WzTOH3BzNkLdXlEGGovhxkCH9g5D5yGG44oQ2QnJHTY7XYtZ6P6lpjHD8Ut_3ryStmDlfkdZe75jlrWgQIiSmGv-YnjHfsSUiXjtpHoisFJRF6XQkItrPcnc-_j5ksvqMrsE9wSKlJzr6bd9uoE=">parks with art installations near Sunnyvale CA</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHgYVAOcAnpoYJzgDSWKL6cM0L-MQq5_i4B_ny_A3zcxKrTUxwJKDOfNZT1r5FNFG5prfrnHXMx02DErSXnRkTXFZXp-pmDPN9_IWrqkE8nKcL8al9yXj2vFGXfsJaac2sq0nTExF9IboyYscFaYB0UJicD1sNFXqcgbe0Xd1L16jStfV_wvkYO9wltbE-xN69zD2a1OBiltr4y5TodRpXXCCPYz_-AlQ==">affordable things to do in Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQExB6mluf4WW3iLys5k6BNJacCNDFoTT1r8oD9JiDqMGfZLWGaOf8daAQgRm6IxYBVY1ndzNIb-iAgGyyhWMmubvrb0Q9zhiMNlLebH5ozgVysQSaLwIGtV5yjJlj3juCzTtc8AZuNWwU2jZghXtc1Np89EOonAFPk_sL9PlF9DWpSjvxUVrGoukLoAT1c9JCL13GeeJW2XZMhDOQGUP4mrzSXDRSIvyUhJ65U=">botanical gardens near Sunnyvale CA free</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFnLR-bhg0aPgVMHUOf0di0XUXXA7XrTXnVGdwkCZoZVfHSlBacXNqWym4CgRqW0ukm7w_jJU_FlVmwXdxptWHH2VMeul4eSXDIEd98feyjr0_Xn2tBpHIUOleRmqSNnYoaj9pC0K3eYBFNxrdeMC01CHeFYmDjAJU-naAzoGbrLcacloFK4MNg7-tH8Ua1oE0cbSxVRsoOwOGJkrMdmuUMoqYZfDowck8g5V273aluIkCFJvuDn2U=">free evening events near Sunnyvale CA March 13 2026</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGJCXaMi2zX8KCEv_S8rgMX8g3tFMZua71NGdg_yu4qhYVGC-UbABUllfGVccCotf-Y0Y2_ZOi0-TGRhf1ZeHbM8r1PO88CtvN0431sIBaRAdG5YvH66Fqia8AArn2hbnlNcG3leUIHrYl4DK63wyNjvAFJcswwkwxHwN539pSXWtCyuuXKxMH-qwaQ1S7cVGjJI3B3MmaBK5LFKEQu">cheap eats Palo Alto artsy</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'free art museums near Sunnyvale CA',
#     'affordable art galleries Palo Alto',
#     'outdoor sculpture parks near Sunnyvale CA free',
#     'botanical gardens near Sunnyvale CA free',
#     'parks with art installations near Sunnyvale CA',
#     <... 5 more items ...>,
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=894,
#   prompt_token_count=256,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=256
#     ),
#   ],
#   thoughts_token_count=1708,
#   tool_use_prompt_token_count=704,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=704
#     ),
#   ],
#   total_token_count=3562
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-edcff966-442f-4ab6-9a39-75649a57b6d1' author='day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='add75afc-4b53-44f3-a24b-06cc897e5ddd' timestamp=1773389695.061868
#
# --------------------------------------------------
# ✅ Final Response:
# Here's a relaxing and artsy day trip near Sunnyvale, CA, designed with affordability in mind for Friday, March 13, 2026:
#
# ## Relaxing & Artsy Day Trip near Sunnyvale, CA (Affordable)
#
# This itinerary focuses on free or low-cost artistic and serene experiences, with suggestions for affordable meals.
#
# ### Morning (11:00 AM - 1:30 PM): Immerse in Art and Sculptures
#
# *   **Cantor Arts Center at Stanford University & Rodin Sculpture Garden (Stanford, CA)**
#     *   **Description:** Begin your day exploring the diverse collections at the Cantor Arts Center, which features art from various cultures and periods. Afterward, take a leisurely stroll through the adjacent Rodin Sculpture Garden, an impressive outdoor space showcasing over 20 bronze sculptures by Auguste Rodin. The blend of indoor gallery space and the tranquil outdoor garden provides a perfect artsy and relaxing start to your day.
#     *   **Cost:** Free admission.
#     *   **Operating Hours (March 13, 2026):** Open Wednesday to Sunday, 11 AM - 5 PM.
#
# ### Lunch (1:30 PM - 2:30 PM): Affordable Bites in Palo Alto
#
# *   **Oren's Hummus or Mediterranean Wraps (Palo Alto, CA)**
#     *   **Description:** Head to downtown Palo Alto for an affordable and delicious lunch. Oren's Hummus offers a delightful array of hummus plates, shawarma wraps, and falafel bowls with fresh ingredients and generous portions. Alternatively, Mediterranean Wraps is known for its tasty and filling Mediterranean cuisine, with options like falafel and kufta kebabs at reasonable prices.
#     *   **Cost:** Affordable (expect to spend $10-$20 per person).
#
# ### Afternoon (2:30 PM - 4:30 PM): Serenity in Bloom
#
# *   **Elizabeth F. Gamble Garden (Palo Alto, CA)**
#     *   **Description:** After lunch, find tranquility at the Elizabeth F. Gamble Garden, a historic 2.5-acre property featuring formal gardens and a beautiful rose garden. It's a wonderful place for a peaceful walk, offering benches to sit and relax amidst vibrant flora.
#     *   **Cost:** Free admission.
#     *   **Operating Hours (March 13, 2026):** Generally open during daylight hours; confirm specific closing time for Friday in March, but typically accessible until at least 5 PM.
#
# ### Late Afternoon / Early Evening (4:30 PM - 6:00 PM): Sunnyvale Public Art Walk
#
# *   **Self-Guided Public Art Tour (Sunnyvale, CA)**
#     *   **Description:** Return to Sunnyvale and take a relaxing self-guided tour of the city's extensive public art collection. Sunnyvale boasts over 200 public art pieces, including the "Sun Flair" program which features 26 sun sculptures uniquely transformed by local artists, installed in various city parks. You can view these pieces, often including murals and sculptures, in an outdoor setting.
#     *   **Cost:** Free.
#
# ### Evening (6:00 PM onwards): Affordable Dinner & Relaxed Ambiance
#
# *   **Dinner in Sunnyvale (Various Locations)**
#     *   **Description:** Enjoy an affordable dinner in Sunnyvale. Options could include local eateries on Murphy Avenue or exploring diverse cuisines available in the area. For a casual and budget-friendly meal, consider places with good reviews for a relaxed atmosphere.
#     *   **Cost:** Affordable (expect to spend $15-$25 per person).
#
# Enjoy your relaxing and artsy day trip!
# --------------------------------------------------

# %% [markdown]
# ---
# ## Part 2: Supercharging Agents with Custom Tools 🛠️
#
# So far, we've used the powerful built-in `GoogleSearch` tool. But the true power of agents comes from connecting them to your own logic and data sources.
#
# This is where **custom tools** come in. Let's explore three patterns for giving your agent new skills, using real-world, practical examples.

# %% [markdown]
# ### 2.1 The Simple `FunctionTool`: Calling a Real-Time Weather API
#
# The most direct way to create a tool is by writing a Python function. This is perfect for synchronous tasks like fetching data from an API.
#
# **Key Concept:** The function's **docstring** is critical. The ADK uses it as the tool's official description, which the LLM reads to understand its purpose, parameters, and when to use it.
#
# In this example, we'll create a tool that calls the **free, public U.S. National Weather Service API** to get a real-time forecast. No API key needed!

# %%
# --- Tool Definition: A function that calls a live public API ---
import requests
import json

# A simple lookup to avoid needing a separate geocoding API for this example
LOCATION_COORDINATES = {
    "sunnyvale": "37.3688,-122.0363",
    "san francisco": "37.7749,-122.4194",
    "lake tahoe": "39.0968,-120.0324"
}

def get_live_weather_forecast(location: str) -> dict:
    """Gets the current, real-time weather forecast for a specified location in the US.AIzaSyBTkbMu4s1HW2qupEGOI8lIEuqfXYUMz_0

    Args:
        location: The city name, e.g., "San Francisco".

    Returns:
        A dictionary containing the temperature and a detailed forecast.
    """
    print(f"🛠️ TOOL CALLED: get_live_weather_forecast(location='{location}')")

    # Find coordinates for the location
    normalized_location = location.lower()
    coords_str = None
    for key, val in LOCATION_COORDINATES.items():
        if key in normalized_location:
            coords_str = val
            break
    if not coords_str:
        return {"status": "error", "message": f"I don't have coordinates for {location}."}

    try:
        # NWS API requires 2 steps: 1. Get the forecast URL from the coordinates.
        points_url = f"https://api.weather.gov/points/{coords_str}"
        headers = {"User-Agent": "ADK Example Notebook"}
        points_response = requests.get(points_url, headers=headers)
        points_response.raise_for_status() # Raise an exception for bad status codes
        forecast_url = points_response.json()['properties']['forecast']

        # 2. Get the actual forecast from the URL.
        forecast_response = requests.get(forecast_url, headers=headers)
        forecast_response.raise_for_status()

        # Extract the relevant forecast details
        current_period = forecast_response.json()['properties']['periods'][0]
        return {
            "status": "success",
            "temperature": f"{current_period['temperature']}°{current_period['temperatureUnit']}",
            "forecast": current_period['detailedForecast']
        }
    except requests.exceptions.RequestException as e:
        return {"status": "error", "message": f"API request failed: {e}"}

# --- Agent Definition: An agent that USES the new tool ---

weather_agent = Agent(
    name="weather_aware_planner",
    model="gemini-2.5-flash",
    description="A trip planner that checks the real-time weather before making suggestions.",
    instruction="You are a cautious trip planner. Before suggesting any outdoor activities, you MUST use the `get_live_weather_forecast` tool to check conditions. Incorporate the live weather details into your recommendation.",
    tools=[get_live_weather_forecast]
)

print(f"🌦️ Agent '{weather_agent.name}' is created and can now call a live weather API!")
# Out:
# 🌦️ Agent 'weather_aware_planner' is created and can now call a live weather API!

# %%
# --- Let's test the Weather-Aware Planner ---

async def run_weather_planner_test():
    weather_session = await session_service.create_session(app_name=weather_agent.name, user_id=my_user_id)
    query = "I want to go hiking near Lake Tahoe, what's the weather like?"
    print(f"🗣️ User Query: '{query}'")
    await run_agent_query(weather_agent, query, weather_session, my_user_id)

await run_weather_planner_test()
# Out:
# 🗣️ User Query: 'I want to go hiking near Lake Tahoe, what's the weather like?'
#
# 🚀 Running query for agent: 'weather_aware_planner' in session: 'a7bf3b77-acd6-4ddb-8f37-139f18ed39ad'...
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'location': 'Lake Tahoe'
#         },
#         id='adk-94ddba84-657c-46d3-baaa-87c460bde14c',
#         name='get_live_weather_forecast'
#       ),
#       thought_signature=b'\n\x9c\x02\x01\xbe>\xf6\xfb\x8b(\xdf\xdeb\x994\x89\xf5\xab\x86\xf0r[\x82l\xc8\xc4r\x9b\xda\x01l\x9a\xb2\xc6\xb2\xdd\xe7J\x865\xea\xcf9\xa6\x85\x93s\xa2\xd8\x93L\xf9\x10->\xebX\xac\xb6\xc4\x9d+\xc5\x00\xfdv\xc0\xad\xe2\x89\xb6\xe0\xc3\xdf\x99\xab\x9c\xf9\xaaU\xd8:\xd7>\xd4cP:\xc0XQ\xf6\xe7f\xb7ip...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=20,
#   prompt_token_count=187,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=187
#     ),
#   ],
#   thoughts_token_count=55,
#   total_token_count=262
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-0c41e061-2c82-424f-83e2-c1ff23d8e53f' author='weather_aware_planner' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='1b273a44-6685-4b8b-963d-b140213d2658' timestamp=1773389734.518817
# 🛠️ TOOL CALLED: get_live_weather_forecast(location='Lake Tahoe')
# EVENT: model_version=None content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-94ddba84-657c-46d3-baaa-87c460bde14c',
#         name='get_live_weather_forecast',
#         response={
#           'forecast': 'Partly cloudy, with a low around 41. Southwest wind around 5 mph.',
#           'status': 'success',
#           'temperature': '41°F'
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-0c41e061-2c82-424f-83e2-c1ff23d8e53f' author='weather_aware_planner' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='cf8622b0-2711-4a79-9edd-39d7e9f5a5d5' timestamp=1773389736.32788
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="The weather near Lake Tahoe is partly cloudy with a low around 41°F and a southwest wind around 5 mph. It's a bit chilly, so if you plan on hiking, make sure to dress in layers and be prepared for cool temperatures.",
#       thought_signature=b"\n\xcd\x02\x01\xbe>\xf6\xfb1\xb9\xaaf\xc8y\xf2\xd2\xb4\x7f\xd8\xdd\xbc\xeb\xea\xdc\xc0\xd8\x1d\x81o\x9a\x16\xba\xb3\xae4|\xb3\x9f\xa9\xcf\xb5'\x94A\xd4W\x91\xe1%U>hQ\x85Q\xcc=\x7f\xca\xa8\xf3\x94<z_\xc1$:\xe75\xad\x05\t\xa3d\x9b\xf9\xc6\xe7*\x8c$\x03\xb5M\xca\x8aE:\xf0\xd5\xef\xb83\x82\xdb\x07...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=53,
#   prompt_token_count=258,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=258
#     ),
#   ],
#   thoughts_token_count=65,
#   total_token_count=376
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-0c41e061-2c82-424f-83e2-c1ff23d8e53f' author='weather_aware_planner' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='e94a0ca0-a6fb-4702-9da7-8a17b1ed23be' timestamp=1773389736.329433
#
# --------------------------------------------------
# ✅ Final Response:
# The weather near Lake Tahoe is partly cloudy with a low around 41°F and a southwest wind around 5 mph. It's a bit chilly, so if you plan on hiking, make sure to dress in layers and be prepared for cool temperatures.
# --------------------------------------------------

# %% [markdown]
# ## 2.2 The Agent-as-a-Tool: Consulting a Specialist 🧑‍🍳
#
# Why build one agent that does everything when you can build a **team of specialist agents?** The **Agent-as-a-Tool** pattern allows one agent to delegate a task to another agent.
#
# **Key Concept:** This is different from a sub-agent. When Agent A calls Agent B as a tool, Agent B's response is passed **back to Agent A**. Agent A then uses that information to form its own final response to the user. It's a powerful way to compose complex behaviors from simpler, focused, and reusable agents.

# %% [markdown]
# ### How It Works
#
# Our top-level agent, the `trip_data_concierge_agent`, acts as the **Orchestrator**. It has two tools at its disposal:
#
# 1.  `call_db_agent`: A function that internally calls our `db_agent` to fetch raw data.
# 2.  `call_concierge_agent`: A function that calls the `concierge_agent`.
#
# The `concierge_agent` itself has a tool: the `food_critic_agent`.
#
# The flow for a complex query is:
#
# 1.  **User** asks the `trip_data_concierge_agent` for a hotel and a nearby restaurant.
# 2.  The **Orchestrator** first calls `call_db_agent` to get hotel data.
# 3.  The data is saved in `tool_context.state`.
# 4.  The **Orchestrator** then calls `call_concierge_agent`, which retrieves the hotel data from the context.
# 5.  The `concierge_agent` receives the request and decides it needs to use its own tool, the `food_critic_agent`.
# 6.  The `food_critic_agent` provides a witty recommendation.
# 7.  The `concierge_agent` gets the critic's response and politely formats it.
# 8.  This final, polished response is returned to the **Orchestrator**, which presents it to the user.

# %% [markdown]
#                          +-----------------------------------------------------------+
#                          |              🧭 Trip Data Concierge Agent                 |
#                          |-----------------------------------------------------------|
#                          |  Model: gemini-2.5-flash                                  |
#                          |  Description:                                             |
#                          |   Orchestrates database query and travel recommendation  |
#                          |-----------------------------------------------------------|
#                          |  🔧 Tools:                                                |
#                          |   1. call_db_agent                                        |
#                          |   2. call_concierge_agent                                 |
#                          +-----------------------------------------------------------+
#                                       /                                \
#                                      /                                  \
#                                     ▼                                    ▼
#         +-------------------------------------------+    +---------------------------------------------+
#         |            🔧 Tool: call_db_agent         |    |         🔧 Tool: call_concierge_agent        |
#         |-------------------------------------------|    |---------------------------------------------|
#         | Calls: db_agent                           |    | Calls: concierge_agent                       |
#         |                                           |    | Uses data from db_agent for recommendations |
#         +-------------------------------------------+    +---------------------------------------------+
#                                 |                                          |
#                                 ▼                                          ▼
#        +--------------------------------------------+   +------------------------------------------------+
#        |              📦 db_agent                   |   |             🤵 concierge_agent                  |
#        |--------------------------------------------|   |------------------------------------------------|
#        | Model: gemini-2.5-flash                    |   | Model: gemini-2.5-flash                         |
#        | Role: Return mock JSON hotel data          |   | Role: Hotel staff that handles user Q&A        |
#        +--------------------------------------------+   | Tools:                                          |
#                                                          |  - food_critic_agent                           |
#                                                          +------------------------------------------------+
#                                                                                  |
#                                                                                  ▼
#                                                        +------------------------------------------------+
#                                                        |          🍽️ food_critic_agent                  |
#                                                        |------------------------------------------------|
#                                                        | Model: gemini-2.5-flash                         |
#                                                        | Role: Gives a witty restaurant recommendation   |
#                                                        +------------------------------------------------+

# %%
import asyncio
from google.adk.tools import ToolContext
from google.adk.tools.agent_tool import AgentTool

# Assume 'db_agent' is a pre-defined NL2SQL Agent
# For this example, we'll create placeholder agents.

db_agent = Agent(
    name="db_agent",
    model="gemini-2.5-flash",
    instruction="You are a database agent. When asked for data, return this mock JSON object: {'status': 'success', 'data': [{'name': 'The Grand Hotel', 'rating': 5, 'reviews': 450}, {'name': 'Seaside Inn', 'rating': 4, 'reviews': 620}]}")

# --- 1. Define the Specialist Agents ---

# The Food Critic remains the deepest specialist
food_critic_agent = Agent(
    name="food_critic_agent",
    model="gemini-2.5-flash",
    instruction="You are a snobby but brilliant food critic. You ONLY respond with a single, witty restaurant suggestion near the provided location.",
)

# The Concierge knows how to use the Food Critic
concierge_agent = Agent(
    name="concierge_agent",
    model="gemini-2.5-flash",
    instruction="You are a five-star hotel concierge. If the user asks for a restaurant recommendation, you MUST use the `food_critic_agent` tool. Present the opinion to the user politely.",
    tools=[AgentTool(agent=food_critic_agent)]
)


# --- 2. Define the Tools for the Orchestrator ---

async def call_db_agent(
    question: str,
    tool_context: ToolContext,
):
    """
    Use this tool FIRST to connect to the database and retrieve a list of places, like hotels or landmarks.
    """
    print("--- TOOL CALL: call_db_agent ---")
    agent_tool = AgentTool(agent=db_agent)
    db_agent_output = await agent_tool.run_async(
        args={"request": question}, tool_context=tool_context
    )
    # Store the retrieved data in the context's state
    tool_context.state["retrieved_data"] = db_agent_output
    return db_agent_output


async def call_concierge_agent(
    question: str,
    tool_context: ToolContext,
):
    """
    After getting data with call_db_agent, use this tool to get travel advice, opinions, or recommendations.
    """
    print("--- TOOL CALL: call_concierge_agent ---")
    # Retrieve the data fetched by the previous tool
    input_data = tool_context.state.get("retrieved_data", "No data found.")

    # Formulate a new prompt for the concierge, giving it the data context
    question_with_data = f"""
    Context: The database returned the following data: {input_data}

    User's Request: {question}
    """

    agent_tool = AgentTool(agent=concierge_agent)
    concierge_output = await agent_tool.run_async(
        args={"request": question_with_data}, tool_context=tool_context
    )
    return concierge_output


# --- 3. Define the Top-Level Orchestrator Agent ---

trip_data_concierge_agent = Agent(
    name="trip_data_concierge",
    model="gemini-2.5-flash",
    description="Top-level agent that queries a database for travel data, then calls a concierge agent for recommendations.",
    tools=[call_db_agent, call_concierge_agent],
    instruction="""
    You are a master travel planner who uses data to make recommendations.

    1.  **ALWAYS start with the `call_db_agent` tool** to fetch a list of places (like hotels) that match the user's criteria.

    2.  After you have the data, **use the `call_concierge_agent` tool** to answer any follow-up questions for recommendations, opinions, or advice related to the data you just found.
    """,
)

print(f"✅ Orchestrator Agent '{trip_data_concierge_agent.name}' is defined and ready.")
# Out:
# ✅ Orchestrator Agent 'trip_data_concierge' is defined and ready.

# %%
# --- Let's test the Trip Data Concierge Agent ---

async def run_trip_data_concierge():
    """
    Sets up a session and runs a query against the top-level
    trip_data_concierge_agent.
    """
    # Create a new, single-use session for this query
    concierge_session = await session_service.create_session(
        app_name=trip_data_concierge_agent.name,
        user_id=my_user_id
    )

    # This query is specifically designed to trigger the full two-step process:
    # 1. Get data from the db_agent.
    # 2. Get a recommendation from the concierge_agent based on that data.
    # query = "Find the top-rated hotels in San Francisco from the database, then suggest a dinner spot near the one with the most reviews."
    query = "Find the top-rated hotels in Bangkok from the database"
    print(f"🗣️ User Query: '{query}'")

    # We call our existing helper function with the top-level orchestrator agent
    await run_agent_query(trip_data_concierge_agent, query, concierge_session, my_user_id)

# Run the test
await run_trip_data_concierge()
# Out:
# 🗣️ User Query: 'Find the top-rated hotels in Bangkok from the database'
#
# 🚀 Running query for agent: 'trip_data_concierge' in session: 'ebdf34ca-5e5c-4c3e-9b22-838366c34407'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'question': 'Find the top-rated hotels in Bangkok'
#         },
#         id='adk-8454ee31-bd19-44c7-b82c-48ced7dc883c',
#         name='call_db_agent'
#       ),
#       thought_signature=b'\n\xa7\x02\x01\xbe>\xf6\xfb\x9fH\x98\xf3/\xd3\x11@\xa1\xd6\xbf\xa9[\xb0U\x13e}\xce\xc9\xb1\nyE>\xefl p[\x02\x08\xe3\xf0\xd3DeC\xc2\xb8\xd7\xb3\xebD9\x82e\x17\xed\xc4[\x89T\xec\xe0Z\xf4q\x0eJs\x0fb>\xa3\xf2j\x19}\xe2\xf8{L\xfeq\xbd\xf2Q\x086o\xd4\t\xf5\xce\xa5\\9\xe5...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=24,
#   prompt_token_count=278,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=278
#     ),
#   ],
#   thoughts_token_count=65,
#   total_token_count=367
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-926864e2-79fe-4463-8c81-f21d760a46cd' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='75434f2f-20bf-4050-8464-02dfcb88060d' timestamp=1773389769.719338
# --- TOOL CALL: call_db_agent ---
# EVENT: model_version=None content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-8454ee31-bd19-44c7-b82c-48ced7dc883c',
#         name='call_db_agent',
#         response={
#           'result': """I can provide you with hotel data, but I do not have location information to filter by 'Bangkok'. Here is the data available:
#
# ```json
# {
#   "status": "success",
#   "data": [
#     {
#       "name": "The Grand Hotel",
#       "rating": 5,
#       "reviews": 450
#     },
#     {
#       "name": "Seaside Inn",
#       "rating": 4,
#       "reviews": 620
#     }
#   ]
# }
# ```"""
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-926864e2-79fe-4463-8c81-f21d760a46cd' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={'retrieved_data': 'I can provide you with hotel data, but I do not have location information to filter by \'Bangkok\'. Here is the data available:\n\n```json\n{\n  "status": "success",\n  "data": [\n    {\n      "name": "The Grand Hotel",\n      "rating": 5,\n      "reviews": 450\n    },\n    {\n      "name": "Seaside Inn",\n      "rating": 4,\n      "reviews": 620\n    }\n  ]\n}\n```'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='062fd06f-4c19-444a-9d57-783abcdbff63' timestamp=1773389776.182105
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'question': 'Given the following hotels: The Grand Hotel with a rating of 5 and 450 reviews, and Seaside Inn with a rating of 4 and 620 reviews, which one is the top-rated hotel?'
#         },
#         id='adk-0b5556a4-f9d2-48e6-8fd4-593452bfb263',
#         name='call_concierge_agent'
#       ),
#       thought_signature=b'\n\xba\x04\x01\xbe>\xf6\xfb\x80\xcf\xb5\x91\xa7\x08\x15\xcf+\xb0\xc7\x80K\x955"\xc2y\t\x90\xa9%\x8a\x19\xa9\x85jEeiKz\xec\x8fPr\x9f6\xd9\x80<\xbc\xd0\xbd\xb5\xc3q\xd4*~\xf8\xf2\xc8\x16`b\xaeEEY\xc5\x10\xf6\x80\xe9\xe6\xf6_\xa0%\xba\x80Dud\x9by\xee\xdb\xa1\xd3\xf1-\x03\x80\xaf\x94 U...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=63,
#   prompt_token_count=447,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=447
#     ),
#   ],
#   thoughts_token_count=126,
#   total_token_count=636
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-926864e2-79fe-4463-8c81-f21d760a46cd' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='ea01cf94-1dda-46db-9a82-5ccfa41cc1a6' timestamp=1773389776.184906
# --- TOOL CALL: call_concierge_agent ---
# EVENT: model_version=None content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='adk-0b5556a4-f9d2-48e6-8fd4-593452bfb263',
#         name='call_concierge_agent',
#         response={
#           'result': 'The top-rated hotel is The Grand Hotel, with a rating of 5 stars.'
#         }
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-926864e2-79fe-4463-8c81-f21d760a46cd' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='0eb65053-a800-4912-ab55-8bd050e6049b' timestamp=1773389779.064742
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text='Based on the available data, The Grand Hotel is the top-rated hotel with a 5-star rating. I do not have location information to confirm if these hotels are in Bangkok.',
#       thought_signature=b'\n\x95\x03\x01\xbe>\xf6\xfb\xd8\xb9\xbf\xfa}\xfe\xe6\xf7\x8e\x1b\xfb\xf7\x85\xad\x13^\x9f\xa8oL\x04\xb0\x92\xdcP\xa4i"\xc4\xd0\x85\xaa\xe1#\xb2\xaci>y\xf3\xb3e4\x8f\xba\xd9\x1c\x9d\xcb\x9d\xaa\xca]\xc6% \xab\xf4C\x8c\x19\x03`\xdah\xdf\xea\xfe\x121w\xbd\xe7\x06\xa3\xa0\xa8\xac\xf1Z\xf0\x92;y\x0ce\xa7{\x9e...'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=38,
#   prompt_token_count=545,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=545
#     ),
#   ],
#   thoughts_token_count=96,
#   total_token_count=679
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-926864e2-79fe-4463-8c81-f21d760a46cd' author='trip_data_concierge' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='03da8e8b-3d3d-4029-bcf5-0c4c3eea55e5' timestamp=1773389779.066748
#
# --------------------------------------------------
# ✅ Final Response:
# Based on the available data, The Grand Hotel is the top-rated hotel with a 5-star rating. I do not have location information to confirm if these hotels are in Bangkok.
# --------------------------------------------------

# %% [markdown]
# ---
# ## Part 3: Agent with a Memory - The Adaptive Planner 🗺️
#
# Now, let's see an agent that not only **remembers** but also **adapts**. We'll challenge the `multi_day_trip_agent` to re-plan part of its itinerary based on our feedback. This is a much more realistic test of conversational AI.

# %% [markdown]
# ```
# +-----------------------------------------------------+
# |         Adaptive Multi-Day Trip Agent 🗺️           |
# |-----------------------------------------------------|
# |  Model: gemini-2.5-flash                            |
# |  Description:                                       |
# |   Builds multi-day travel itineraries step-by-step, |
# |   remembers previous days, adapts to feedback       |
# |-----------------------------------------------------|
# |  🔧 Tools:                                          |
# |   - Google Search                                   |
# |-----------------------------------------------------|
# |  🧠 Capabilities:                                   |
# |   - Memory of past conversation & preferences       |
# |   - Progressive planning (1 day at a time)          |
# |   - Adapts to user feedback                         |
# |   - Ensures activity variety across days            |
# +-----------------------------------------------------+
#
#             ▲
#             |
#     +---------------------------+
#     |     User Interaction      |
#     |---------------------------|
#     | - Destination             |
#     | - Trip duration           |
#     | - Interests & feedback    |
#     +---------------------------+
#
#             |
#             ▼
#
# +-----------------------------------------------------+
# |        Day-by-Day Itinerary Generation              |
# |-----------------------------------------------------|
# |  🗓️ Day N Output (Markdown format):                 |
# |   - Morning / Afternoon / Evening activities        |
# |   - Personalized & context-aware                    |
# |   - Changes accepted, feedback acknowledged         |
# +-----------------------------------------------------+
#
#             |
#             ▼
#
# +-----------------------------------------------------+
# |        Next Day Planning Triggered 🚀               |
# |-----------------------------------------------------|
# | - Builds on prior days                              |
# | - Avoids repetition                                 |
# | - Asks user for confirmation before proceeding      |
# +-----------------------------------------------------+
# ```

# %%
# --- Agent Definition: The Adaptive Planner ---

def create_multi_day_trip_agent():
    """Create the Progressive Multi-Day Trip Planner agent"""
    return Agent(
        name="multi_day_trip_agent",
        model="gemini-2.5-flash",
        description="Agent that progressively plans a multi-day trip, remembering previous days and adapting to user feedback.",
        instruction="""
        You are the "Adaptive Trip Planner" 🗺️ - an AI assistant that builds multi-day travel itineraries step-by-step.

        Your Defining Feature:
        You have short-term memory. You MUST refer back to our conversation to understand the trip's context, what has already been planned, and the user's preferences. If the user asks for a change, you must adapt the plan while keeping the unchanged parts consistent.

        Your Mission:
        1.  **Initiate**: Start by asking for the destination, trip duration, and interests.
        2.  **Plan Progressively**: Plan ONLY ONE DAY at a time. After presenting a plan, ask for confirmation.
        3.  **Handle Feedback**: If a user dislikes a suggestion (e.g., "I don't like museums"), acknowledge their feedback, and provide a *new, alternative* suggestion for that time slot that still fits the overall theme.
        4.  **Maintain Context**: For each new day, ensure the activities are unique and build logically on the previous days. Do not suggest the same things repeatedly.
        5.  **Final Output**: Return each day's itinerary in MARKDOWN format.
        """,
        tools=[google_search]
    )

multi_day_agent = create_multi_day_trip_agent()
print(f"🗺️ Agent '{multi_day_agent.name}' is created and ready to plan and adapt!")
# Out:
# 🗺️ Agent 'multi_day_trip_agent' is created and ready to plan and adapt!

# %% [markdown]
# ### Scenario 3a: Agent WITH Memory (Using a SINGLE Session) ✅
#
# First, let's see the correct way to do it. We will use the **exact same `trip_session` object** for the entire conversation. Watch how the agent remembers the context from Turn 1 to correctly handle the requests in Turn 2 and 3.

# %%
# --- Scenario 2: Testing Adaptation and Memory ---

async def run_adaptive_memory_demonstration():
    print("### 🧠 DEMO 2: AGENT THAT ADAPTS (SAME SESSION) ###")

    # Create ONE session that we will reuse for the whole conversation
    trip_session = await session_service.create_session(
        app_name=multi_day_agent.name,
        user_id=my_user_id
    )
    print(f"Created a single session for our trip: {trip_session.id}")

    # --- Turn 1: The user initiates the trip ---
    query1 = "Hi! I want to plan a 2-day trip to Lisbon, Portugal. I'm interested in historic sites and great local food."
    print(f"\n🗣️ User (Turn 1): '{query1}'")
    await run_agent_query(multi_day_agent, query1, trip_session, my_user_id)

    # --- Turn 2: The user gives FEEDBACK and asks for a CHANGE ---
    # We use the EXACT SAME `trip_session` object!
    query2 = "That sounds pretty good, but I'm not a huge fan of castles. Can you replace the morning activity for Day 1 with something else historical?"
    print(f"\n🗣️ User (Turn 2 - Feedback): '{query2}'")
    await run_agent_query(multi_day_agent, query2, trip_session, my_user_id)

    # --- Turn 3: The user confirms and asks to continue ---
    query3 = "Yes, the new plan for Day 1 is perfect! Please plan Day 2 now, keeping the food theme in mind."
    print(f"\n🗣️ User (Turn 3 - Confirmation): '{query3}'")
    await run_agent_query(multi_day_agent, query3, trip_session, my_user_id)

await run_adaptive_memory_demonstration()
# Out:
# ### 🧠 DEMO 2: AGENT THAT ADAPTS (SAME SESSION) ###
# Created a single session for our trip: e3a29c53-8b0f-4f9c-8868-44b2d1be0796
#
# 🗣️ User (Turn 1): 'Hi! I want to plan a 2-day trip to Lisbon, Portugal. I'm interested in historic sites and great local food.'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: 'e3a29c53-8b0f-4f9c-8868-44b2d1be0796'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Hello! Lisbon is a fantastic choice for history and food. I can definitely help you plan a memorable 2-day trip.
#
# Let's start with **Day 1**:
#
# **Morning:**
# *   Begin your day exploring **Alfama**, Lisbon's oldest district. Wander through its narrow, winding streets, soak in the historic atmosphere, and discover hidden viewpoints.
# *   Visit the **Lisbon Cathedral (Sé de Lisboa)**, a beautiful and historic church that dates back to the 12th century.
# *   Ascend to **São Jorge Castle (Castelo de São Jorge)**, an iconic historic castle offering panoramic views of the city and the Tagus River.
#
# **Lunch:**
# *   Enjoy a traditional Portuguese lunch in Alfama. Look for a local *tasca* (a traditional Portuguese tavern) to try dishes like *Bacalhau à Brás* (codfish with eggs and potatoes) or *Sardinhas Assadas* (grilled sardines).
#
# **Afternoon:**
# *   Explore the elegant **Baixa** district, rebuilt after the 1755 earthquake with a grid-like street plan.
# *   Walk through the charming **Chiado** district, known for its historic theaters, traditional shops, and literary cafes.
# *   Ride the iconic **Santa Justa Lift** for more incredible city views and a unique architectural experience.
#
# **Evening:**
# *   Have dinner in the lively **Bairro Alto** district. This area is famous for its vibrant nightlife and numerous restaurants.
# *   Consider experiencing a traditional **Fado show** with your dinner, a soulful Portuguese music genre that is a UNESCO Intangible Cultural Heritage.
#
# How does this sound for your first day in Lisbon?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata() partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=361,
#   prompt_token_count=331,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=331
#     ),
#   ],
#   thoughts_token_count=146,
#   total_token_count=838
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-ea4f75d8-273d-4e4f-820e-cf83df707c6c' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='e40c138c-6642-40d5-ac45-090eaea51401' timestamp=1773389802.467037
#
# --------------------------------------------------
# ✅ Final Response:
# Hello! Lisbon is a fantastic choice for history and food. I can definitely help you plan a memorable 2-day trip.
#
# Let's start with **Day 1**:
#
# **Morning:**
# *   Begin your day exploring **Alfama**, Lisbon's oldest district. Wander through its narrow, winding streets, soak in the historic atmosphere, and discover hidden viewpoints.
# *   Visit the **Lisbon Cathedral (Sé de Lisboa)**, a beautiful and historic church that dates back to the 12th century.
# *   Ascend to **São Jorge Castle (Castelo de São Jorge)**, an iconic historic castle offering panoramic views of the city and the Tagus River.
#
# **Lunch:**
# *   Enjoy a traditional Portuguese lunch in Alfama. Look for a local *tasca* (a traditional Portuguese tavern) to try dishes like *Bacalhau à Brás* (codfish with eggs and potatoes) or *Sardinhas Assadas* (grilled sardines).
#
# **Afternoon:**
# *   Explore the elegant **Baixa** district, rebuilt after the 1755 earthquake with a grid-like street plan.
# *   Walk through the charming **Chiado** district, known for its historic theaters, traditional shops, and literary cafes.
# *   Ride the iconic **Santa Justa Lift** for more incredible city views and a unique architectural experience.
#
# **Evening:**
# *   Have dinner in the lively **Bairro Alto** district. This area is famous for its vibrant nightlife and numerous restaurants.
# *   Consider experiencing a traditional **Fado show** with your dinner, a soulful Portuguese music genre that is a UNESCO Intangible Cultural Heritage.
#
# How does this sound for your first day in Lisbon?
# --------------------------------------------------
#
#
# 🗣️ User (Turn 2 - Feedback): 'That sounds pretty good, but I'm not a huge fan of castles. Can you replace the morning activity for Day 1 with something else historical?'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: 'e3a29c53-8b0f-4f9c-8868-44b2d1be0796'...
#
# --------------------------------------------------
# ✅ Final Response:
# An error occurred:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 13.893551819s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '13s'}]}}
# --------------------------------------------------
#
#
# 🗣️ User (Turn 3 - Confirmation): 'Yes, the new plan for Day 1 is perfect! Please plan Day 2 now, keeping the food theme in mind.'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: 'e3a29c53-8b0f-4f9c-8868-44b2d1be0796'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Understood! Let's swap out the castle for another historical gem.
#
# Here's the revised **Day 1** plan:
#
# **Morning:**
# *   Begin your day exploring **Alfama**, Lisbon's oldest district. Wander through its narrow, winding streets, soak in the historic atmosphere, and discover hidden viewpoints.
# *   Visit the **Lisbon Cathedral (Sé de Lisboa)**, a beautiful and historic church that dates back to the 12th century.
# *   Instead of the castle, we'll delve into the **Jerónimos Monastery (Mosteiro dos Jerónimos)** in Belém. This stunning UNESCO World Heritage site is a prime example of Manueline architecture and holds immense historical significance, particularly related to Portugal's Age of Discoveries.
#
# **Lunch:**
# *   Enjoy a traditional Portuguese lunch in Alfama. Look for a local *tasca* (a traditional Portuguese tavern) to try dishes like *Bacalhau à Brás* (codfish with eggs and potatoes) or *Sardinhas Assadas* (grilled sardines).
#
# **Afternoon:**
# *   Explore the elegant **Baixa** district, rebuilt after the 1755 earthquake with a grid-like street plan.
# *   Walk through the charming **Chiado** district, known for its historic theaters, traditional shops, and literary cafes.
# *   Ride the iconic **Santa Justa Lift** for more incredible city views and a unique architectural experience.
#
# **Evening:**
# *   Have dinner in the lively **Bairro Alto** district. This area is famous for its vibrant nightlife and numerous restaurants.
# *   Consider experiencing a traditional **Fado show** with your dinner, a soulful Portuguese music genre that is a UNESCO Intangible Cultural Heritage.
#
# ---
#
# Great, with Day 1 sorted, let's move on to **Day 2**, keeping your interest in history and food in mind, and ensuring we explore new areas and experiences:
#
# **Morning:**
# *   Start your day in the historic **Belém** district, where the Jerónimos Monastery is located. After visiting the monastery yesterday, today we can explore more of Belém's maritime history.
# *   Visit the **Belém Tower (Torre de Belém)**, another UNESCO World Heritage site that served as a fortress and a departure point for explorers.
# *   See the **Monument to the Discoveries (Padrão dos Descobrimentos)**, which celebrates Portugal's Age of Exploration and its key figures.
#
# **Lunch:**
# *   While in Belém, you absolutely must try the famous **Pastéis de Belém** at the original factory. These warm, crispy custard tarts are a culinary institution.
# *   For a more substantial lunch, find a local restaurant in Belém offering fresh seafood or other traditional dishes.
#
# **Afternoon:**
# *   Take a scenic tram ride (like Tram 28, if you didn't do it on Day 1, or another route to a new area) or a short taxi/ride-share to the **Mouraria** district, one of Lisbon's most multicultural and historic neighborhoods, considered the birthplace of Fado.
# *   Wander through its winding streets, discovering street art and local shops.
# *   Alternatively, explore the **Principe Real** and **Estrela** neighborhoods, known for their beautiful gardens, palaces, and the stunning **Estrela Basilica**.
#
# **Evening:**
# *   For your farewell dinner, consider dining in the **Cais do Sodré** area, particularly along Rua Nova do Carvalho (the "Pink Street"), which has transformed into a vibrant dining and nightlife spot, offering a wide range of culinary experiences from modern Portuguese to international cuisine.
# *   Reflect on your trip with a final drink at a rooftop bar overlooking the city.
#
# How does this plan for Day 2 sound to you?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata() partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=812,
#   prompt_token_count=752,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=752
#     ),
#   ],
#   thoughts_token_count=166,
#   total_token_count=1730
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-c6ea1a52-add6-463d-8884-123f31e4fdb0' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='0a0291b6-435f-4533-ae57-cfd7331ffe87' timestamp=1773389806.209567
#
# --------------------------------------------------
# ✅ Final Response:
# Understood! Let's swap out the castle for another historical gem.
#
# Here's the revised **Day 1** plan:
#
# **Morning:**
# *   Begin your day exploring **Alfama**, Lisbon's oldest district. Wander through its narrow, winding streets, soak in the historic atmosphere, and discover hidden viewpoints.
# *   Visit the **Lisbon Cathedral (Sé de Lisboa)**, a beautiful and historic church that dates back to the 12th century.
# *   Instead of the castle, we'll delve into the **Jerónimos Monastery (Mosteiro dos Jerónimos)** in Belém. This stunning UNESCO World Heritage site is a prime example of Manueline architecture and holds immense historical significance, particularly related to Portugal's Age of Discoveries.
#
# **Lunch:**
# *   Enjoy a traditional Portuguese lunch in Alfama. Look for a local *tasca* (a traditional Portuguese tavern) to try dishes like *Bacalhau à Brás* (codfish with eggs and potatoes) or *Sardinhas Assadas* (grilled sardines).
#
# **Afternoon:**
# *   Explore the elegant **Baixa** district, rebuilt after the 1755 earthquake with a grid-like street plan.
# *   Walk through the charming **Chiado** district, known for its historic theaters, traditional shops, and literary cafes.
# *   Ride the iconic **Santa Justa Lift** for more incredible city views and a unique architectural experience.
#
# **Evening:**
# *   Have dinner in the lively **Bairro Alto** district. This area is famous for its vibrant nightlife and numerous restaurants.
# *   Consider experiencing a traditional **Fado show** with your dinner, a soulful Portuguese music genre that is a UNESCO Intangible Cultural Heritage.
#
# ---
#
# Great, with Day 1 sorted, let's move on to **Day 2**, keeping your interest in history and food in mind, and ensuring we explore new areas and experiences:
#
# **Morning:**
# *   Start your day in the historic **Belém** district, where the Jerónimos Monastery is located. After visiting the monastery yesterday, today we can explore more of Belém's maritime history.
# *   Visit the **Belém Tower (Torre de Belém)**, another UNESCO World Heritage site that served as a fortress and a departure point for explorers.
# *   See the **Monument to the Discoveries (Padrão dos Descobrimentos)**, which celebrates Portugal's Age of Exploration and its key figures.
#
# **Lunch:**
# *   While in Belém, you absolutely must try the famous **Pastéis de Belém** at the original factory. These warm, crispy custard tarts are a culinary institution.
# *   For a more substantial lunch, find a local restaurant in Belém offering fresh seafood or other traditional dishes.
#
# **Afternoon:**
# *   Take a scenic tram ride (like Tram 28, if you didn't do it on Day 1, or another route to a new area) or a short taxi/ride-share to the **Mouraria** district, one of Lisbon's most multicultural and historic neighborhoods, considered the birthplace of Fado.
# *   Wander through its winding streets, discovering street art and local shops.
# *   Alternatively, explore the **Principe Real** and **Estrela** neighborhoods, known for their beautiful gardens, palaces, and the stunning **Estrela Basilica**.
#
# **Evening:**
# *   For your farewell dinner, consider dining in the **Cais do Sodré** area, particularly along Rua Nova do Carvalho (the "Pink Street"), which has transformed into a vibrant dining and nightlife spot, offering a wide range of culinary experiences from modern Portuguese to international cuisine.
# *   Reflect on your trip with a final drink at a rooftop bar overlooking the city.
#
# How does this plan for Day 2 sound to you?
# --------------------------------------------------

# %% [markdown]
# ### Scenario 3b: Agent WITHOUT Memory (Using SEPARATE Sessions) ❌
#
# Now, let's see what happens if we mess up our session management. Here, we'll give the agent a case of amnesia by creating a **brand new, separate session for each turn**.
#
# Pay close attention to the agent's response to the second query. Because it's in a new session, it has no memory of the trip to Lisbon we just discussed!

# %%
# --- Scenario 2b: Demonstrating Memory FAILURE ---

async def run_memory_failure_demonstration():
    print("\n" + "#"*60)
    print("### 🧠 DEMO 2b: AGENT WITH AMNESIA (SEPARATE SESSIONS) ###")
    print("#"*60)

    # --- Turn 1: The user initiates the trip in the FIRST session ---
    query1 = "Hi! I want to plan a 2-day trip to Lisbon, Portugal. I'm interested in historic sites and great local food."
    session_one = await session_service.create_session(
        app_name=multi_day_agent.name,
        user_id=my_user_id
    )
    print(f"\nCreated a session for Turn 1: {session_one.id}")
    print(f"🗣️ User (Turn 1): '{query1}'")
    await run_agent_query(multi_day_agent, query1, session_one, my_user_id)

    # --- Turn 2: The user asks to continue... but in a completely NEW session ---
    query2 = "Yes, that looks perfect! Please plan Day 2."
    session_two = await session_service.create_session(
        app_name=multi_day_agent.name,
        user_id=my_user_id
    )
    print(f"\nCreated a BRAND NEW session for Turn 2: {session_two.id}")
    print(f"🗣️ User (Turn 2): '{query2}'")
    await run_agent_query(multi_day_agent, query2, session_two, my_user_id)

await run_memory_failure_demonstration()
# Out:
# ############################################################
# ### 🧠 DEMO 2b: AGENT WITH AMNESIA (SEPARATE SESSIONS) ###
# ############################################################
#
# Created a session for Turn 1: 013113b5-5d15-44db-9d0c-c74f7b280931
# 🗣️ User (Turn 1): 'Hi! I want to plan a 2-day trip to Lisbon, Portugal. I'm interested in historic sites and great local food.'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: '013113b5-5d15-44db-9d0c-c74f7b280931'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Hello! Great choice, Lisbon is a fantastic city with a rich history and delicious food. I can definitely help you plan your 2-day trip.
#
# Let's start with **Day 1**. How about this:
#
# **Day 1: Alfama and Baixa Exploration**
#
# *   **Morning (9:00 AM - 1:00 PM): Alfama District & São Jorge Castle**
#     *   Begin your day exploring Alfama, Lisbon's oldest district. Wander through its narrow, winding streets, soak in the historic atmosphere, and discover hidden viewpoints.
#     *   Visit the iconic São Jorge Castle (Castelo de São Jorge) for panoramic views of the city and the Tagus River, along with a delve into its rich history.
# *   **Lunch (1:00 PM - 2:30 PM): Traditional Portuguese Lunch in Alfama**
#     *   Enjoy a traditional Portuguese lunch in one of Alfama's charming local restaurants. Try Bacalhau à Brás (codfish with scrambled eggs and potatoes) or grilled sardines.
# *   **Afternoon (2:30 PM - 6:00 PM): Baixa District & Rossio Square**
#     *   Head down to the Baixa district, rebuilt after the 1755 earthquake. Admire its neoclassical architecture and grid-like streets.
#     *   Explore Rossio Square (Praça do Rossio), a lively central hub with beautiful fountains and statues.
#     *   Consider a ride on the Santa Justa Lift for unique views (though it can have long queues).
# *   **Evening (7:00 PM onwards): Dinner & Fado Show in Alfama**
#     *   Return to Alfama for a memorable dinner, possibly at a restaurant offering live Fado music – Portugal's traditional melancholic song.
#
# How does this sound for your first day in Lisbon?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata() partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=401,
#   prompt_token_count=331,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=331
#     ),
#   ],
#   thoughts_token_count=56,
#   total_token_count=788
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-66ec51b0-4e96-43bf-9b3e-e227e077c437' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='36613af9-39b7-441f-956a-4e03abec1aab' timestamp=1773389817.938021
#
# --------------------------------------------------
# ✅ Final Response:
# Hello! Great choice, Lisbon is a fantastic city with a rich history and delicious food. I can definitely help you plan your 2-day trip.
#
# Let's start with **Day 1**. How about this:
#
# **Day 1: Alfama and Baixa Exploration**
#
# *   **Morning (9:00 AM - 1:00 PM): Alfama District & São Jorge Castle**
#     *   Begin your day exploring Alfama, Lisbon's oldest district. Wander through its narrow, winding streets, soak in the historic atmosphere, and discover hidden viewpoints.
#     *   Visit the iconic São Jorge Castle (Castelo de São Jorge) for panoramic views of the city and the Tagus River, along with a delve into its rich history.
# *   **Lunch (1:00 PM - 2:30 PM): Traditional Portuguese Lunch in Alfama**
#     *   Enjoy a traditional Portuguese lunch in one of Alfama's charming local restaurants. Try Bacalhau à Brás (codfish with scrambled eggs and potatoes) or grilled sardines.
# *   **Afternoon (2:30 PM - 6:00 PM): Baixa District & Rossio Square**
#     *   Head down to the Baixa district, rebuilt after the 1755 earthquake. Admire its neoclassical architecture and grid-like streets.
#     *   Explore Rossio Square (Praça do Rossio), a lively central hub with beautiful fountains and statues.
#     *   Consider a ride on the Santa Justa Lift for unique views (though it can have long queues).
# *   **Evening (7:00 PM onwards): Dinner & Fado Show in Alfama**
#     *   Return to Alfama for a memorable dinner, possibly at a restaurant offering live Fado music – Portugal's traditional melancholic song.
#
# How does this sound for your first day in Lisbon?
# --------------------------------------------------
#
#
# Created a BRAND NEW session for Turn 2: a6af8970-4495-4f7b-9be1-29476815a924
# 🗣️ User (Turn 2): 'Yes, that looks perfect! Please plan Day 2.'
#
# 🚀 Running query for agent: 'multi_day_trip_agent' in session: 'a6af8970-4495-4f7b-9be1-29476815a924'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Great! To help me plan Day 2 and the rest of your trip, could you please tell me:
#
# *   **What is your destination?** (e.g., Paris, Tokyo, Yellowstone National Park)
# *   **How many days will your trip be in total?**
# *   **What are your general interests or things you'd like to experience?** (e.g., history, food, nature, art, adventure, relaxation)
#
# Once I have this information, I can start crafting your itinerary, beginning with Day 1!"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata() partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=116,
#   prompt_token_count=314,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=314
#     ),
#   ],
#   thoughts_token_count=237,
#   total_token_count=667
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-ee703d34-e8a1-4757-bffe-f7c2125bd181' author='multi_day_trip_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=None branch=None id='bbae65fa-7dbd-4bbc-af19-53859fa1aace' timestamp=1773389820.974238
#
# --------------------------------------------------
# ✅ Final Response:
# Great! To help me plan Day 2 and the rest of your trip, could you please tell me:
#
# *   **What is your destination?** (e.g., Paris, Tokyo, Yellowstone National Park)
# *   **How many days will your trip be in total?**
# *   **What are your general interests or things you'd like to experience?** (e.g., history, food, nature, art, adventure, relaxation)
#
# Once I have this information, I can start crafting your itinerary, beginning with Day 1!
# --------------------------------------------------

# %% [markdown]
# See? The agent was confused! It likely asked what destination or what trip we were talking about. Because the second query was in a fresh, isolated session, the agent had no memory of planning Day 1 in Lisbon.
#
# This perfectly illustrates why **managing sessions is the key to building truly conversational agents!**

# %% [markdown]
# ---
# ## 🎉 Congratulations! 🎉
#
# Congratulations on completing your ADK adventure into Tools and Memory! You've taken a massive leap from building single-shot agents to creating dynamic, stateful AI systems.
#
# Let's recap the powerful concepts you've mastered:
#
# - **Fundamental Agent & Tools**: You started by building a "Day Trip Genie" and equipped it with its first tool, GoogleSearch.
#
# - **Custom Function Tools**: You gave your agent a new sense by creating a custom tool to fetch live data from the U.S. National Weather Service API.
#
# - **Agent-as-a-Tool**: You orchestrated a sophisticated hierarchy where agents delegate tasks to other, more specialized agents, creating a collaborative team.
#
# - **The Power of Memory**: Most importantly, you saw firsthand how managing a single, persistent Session allows an agent to remember context, adapt to user feedback, and conduct a meaningful, multi-turn conversation.

# %% [markdown]
# ```
#    __            /\_/\         /\_/\        /\_/\         __             (\__/)
# o-''|\_____/).  ( o.o )       ( -.- )      ( ^_^ )     o-''|\_____/).    ( ^_^ )
#  \_/|_)     )    > ^ <         > * <        >💖<         \_/|_)     )     / >🌸< \
#     \  __  /                                              \  __  /         /   \
#     (_/ (_/                                               (_/ (_/        (___|___)
# ```
